# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
# %matplotlib inline
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'as', 'term', 'of', 'originated']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.compat.v1.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.compat.v1.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.compat.v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.compat.v1.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.compat.v1.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.compat.v1.Session(graph=graph) as session:
  tf.compat.v1.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.163445
# Nearest to are: drug, shag, farragut, roving, densities, edmunds, madelyne, bricklin,
# Nearest to eight: springtime, mlp, feodor, badger, realignment, anteaters, magnetite, bushy,
# Nearest to from: steel, school, bei, nara, renovate, sneaking, init, minstrel,
# Nearest to the: draftsman, cay, ecma, ackerman, astronauts, mailing, likeness, transfection,
# Nearest to however: whipple, obligate, clockless, theo, fantasia, desperately, blister, dcs,
# Nearest to often: equatorial, caspian, huber, hipc, aux, short, sesame, brando,
# Nearest to system: nightmarish, insecurity, barak, fluent, nominal, hominidae, valkyrie, kuru,
# Nearest to many: galicia, blade, annan, tg, january, admired, clay, cisneros,
# Nearest to as: behaves, veracruz, dolmens, phylogeny, jakarta, mayr, stymied, xliii,
# Nearest to have: astonished, tobin, force, render, narcotics, circassians, deluge, hana,
# Nearest to d: westminster, sustains, adlai, stacy, celsius, bamar, curtain, jiva,
# Nearest to two: spruce, expands, conceptual, participated, syed, hillside, permutations, clarity,
# Nearest to only: herzl, gels, itching, washtenaw, frud, rebekah, badge, turismo,
# Nearest to his: camcorders, behaviors, deflect, henri, emptied, csce, lvarez, convened,
# Nearest to and: conservatory, cas, unrwa, schiavo, merges, hipparcos, satisfaction, beings,
# Nearest to four: generally, truthfulness, eater, articulated, biola, ship, byng, recoup,
# Average loss at step 2000: 4.375946
# Average loss at step 4000: 3.882344
# Average loss at step 6000: 3.799275
# Average loss at step 8000: 3.751849
# Average loss at step 10000: 3.628057
# Nearest to are: were, is, was, have, hostile, telecoms, manuel, acetaminophen,
# Nearest to eight: nine, seven, six, five, four, zero, one, three,
# Nearest to from: in, and, between, into, porn, sneaking, on, by,
# Nearest to the: its, his, their, a, this, hermitian, neu, provable,
# Nearest to however: hasty, obligate, within, although, theo, blister, whipple, fantasia,
# Nearest to often: dualities, that, also, equatorial, bhaskara, usually, chem, extras,
# Nearest to system: barak, nominal, reflectance, insecurity, lowers, kuru, chipsets, longstanding,
# Nearest to many: nissan, annan, gobi, agnes, galicia, several, some, other,
# Nearest to as: casualties, frankenchrist, maize, without, electrodes, superstition, avenues, veracruz,
# Nearest to have: had, has, be, were, are, ayya, hayes, narcotics,
# Nearest to d: sustains, rehearsing, adlai, portal, judgment, lebowski, b, mandrake,
# Nearest to two: one, three, five, four, seven, zero, kib, six,
# Nearest to only: pallas, gloria, benzodiazepine, even, decorative, anic, warheads, educating,
# Nearest to his: their, the, s, her, deflect, pets, its, optimizations,
# Nearest to and: or, from, with, in, for, etc, on, by,
# Nearest to four: five, three, seven, eight, six, zero, nine, two,
# Average loss at step 12000: 3.581040
# Average loss at step 14000: 3.612503
# Average loss at step 16000: 3.584322
# Average loss at step 18000: 3.574049
# Average loss at step 20000: 3.546178
# Nearest to are: were, is, have, be, telecoms, monday, belongings, zork,
# Nearest to eight: nine, six, five, seven, four, zero, three, two,
# Nearest to from: into, by, in, between, sneaking, through, during, playboys,
# Nearest to the: its, their, his, a, this, an, secretaries, our,
# Nearest to however: but, although, obligate, within, that, which, fricative, francorum,
# Nearest to often: usually, sometimes, also, generally, dualities, that, equatorial, not,
# Nearest to system: reflectance, lowers, chipsets, longstanding, fail, systems, hominidae, barak,
# Nearest to many: some, several, these, all, nissan, such, other, agnes,
# Nearest to as: by, superstition, with, scheldt, pro, postal, rumford, before,
# Nearest to have: had, has, were, be, are, ayya, hayes, narcotics,
# Nearest to d: b, rehearsing, mandrake, h, lebowski, diamond, adlai, celsius,
# Nearest to two: four, five, three, six, one, eight, seven, nine,
# Nearest to only: pallas, fathers, constellation, gloria, terrains, deficit, repeated, hearsay,
# Nearest to his: their, her, the, its, s, my, cyrenaica, retinue,
# Nearest to and: or, but, in, manuel, of, s, nutmeg, specter,
# Nearest to four: five, six, eight, seven, three, two, nine, zero,
# Average loss at step 22000: 3.530681
# Average loss at step 24000: 3.441045
# Average loss at step 26000: 3.417502
# Average loss at step 28000: 3.474219
# Average loss at step 30000: 3.411743
# Nearest to are: were, is, have, but, be, telecoms, include, dahmer,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to from: into, in, between, sneaking, towards, porn, connective, through,
# Nearest to the: its, their, his, this, a, her, any, executor,
# Nearest to however: but, although, that, cohesion, within, invincible, though, paralleled,
# Nearest to often: usually, sometimes, also, generally, commonly, widely, there, dualities,
# Nearest to system: systems, reflectance, lowers, order, nominal, chipsets, barak, harmonious,
# Nearest to many: some, several, these, all, most, such, those, other,
# Nearest to as: when, postal, xliii, into, maize, without, before, pascha,
# Nearest to have: had, has, are, be, were, ayya, hayes, hammerstein,
# Nearest to d: b, lebowski, diamond, and, okavango, rmi, wildlife, adlai,
# Nearest to two: four, five, three, six, seven, eight, zero, nine,
# Nearest to only: terrains, do, also, dowling, pallas, edsger, until, become,
# Nearest to his: their, her, the, its, retinue, my, s, suicide,
# Nearest to and: or, but, which, who, s, of, nutmeg, quail,
# Nearest to four: six, five, seven, eight, three, two, zero, nine,
# Average loss at step 32000: 3.422393
# Average loss at step 34000: 3.435105
# Average loss at step 36000: 3.366013
# Average loss at step 38000: 3.491134
# Average loss at step 40000: 3.448500
# Nearest to are: were, have, is, telecoms, blackstone, those, including, udp,
# Nearest to eight: nine, six, seven, five, four, zero, three, two,
# Nearest to from: through, into, during, by, under, porn, sneaking, in,
# Nearest to the: its, their, his, any, a, some, this, each,
# Nearest to however: but, although, that, though, cohesion, he, norbert, which,
# Nearest to often: sometimes, usually, also, commonly, generally, widely, now, typically,
# Nearest to system: systems, none, reflectance, global, ezln, nominal, hercules, forgiving,
# Nearest to many: some, several, these, other, various, those, all, most,
# Nearest to as: xliii, rumford, without, nisan, ubuntu, before, when, by,
# Nearest to have: had, has, are, were, be, hayes, ayya, infibulation,
# Nearest to d: b, lebowski, rmi, diamond, adlai, cloth, rehearsing, l,
# Nearest to two: five, three, four, zero, six, seven, one, eight,
# Nearest to only: first, terrains, abstractly, do, just, dowling, until, bianchi,
# Nearest to his: her, their, its, retinue, the, my, nationale, s,
# Nearest to and: or, but, tw, rearrange, gera, repertoire, orbs, which,
# Nearest to four: five, seven, six, three, eight, zero, two, nine,
# Average loss at step 42000: 3.428642
# Average loss at step 44000: 3.277151
# Average loss at step 46000: 3.409298
# Average loss at step 48000: 3.431077
# Average loss at step 50000: 3.445612
# Nearest to are: were, is, have, telecoms, include, including, these, fondness,
# Nearest to eight: seven, nine, six, four, five, zero, three, two,
# Nearest to from: into, through, in, between, osteoarthritis, towards, porn, connective,
# Nearest to the: their, a, his, its, this, secretaries, any, catenary,
# Nearest to however: but, although, that, though, since, and, potters, epping,
# Nearest to often: sometimes, usually, generally, commonly, also, now, widely, typically,
# Nearest to system: systems, ezln, hercules, reflectance, global, parse, unbalanced, none,
# Nearest to many: some, several, these, various, all, those, most, other,
# Nearest to as: xliii, ubuntu, donnell, rumford, tubulin, documented, nilo, nisan,
# Nearest to have: had, has, were, be, are, hayes, ayya, having,
# Nearest to d: b, l, rmi, lebowski, okavango, c, cloth, diamond,
# Nearest to two: four, five, three, six, seven, one, eight, zero,
# Nearest to only: first, dowling, clearly, casimir, also, below, positioned, deficit,
# Nearest to his: her, their, its, my, the, s, retinue, broker,
# Nearest to and: or, but, however, with, recant, although, when, s,
# Nearest to four: five, seven, eight, six, three, nine, two, zero,
# Average loss at step 52000: 3.454162
# Average loss at step 54000: 3.428349
# Average loss at step 56000: 3.406713
# Average loss at step 58000: 3.285448
# Average loss at step 60000: 3.381946
# Nearest to are: were, is, telecoms, have, include, those, these, be,
# Nearest to eight: nine, six, five, seven, four, three, two, zero,
# Nearest to from: through, into, during, hatcher, sneaking, towards, in, since,
# Nearest to the: their, its, his, some, a, many, raisins, executor,
# Nearest to however: but, although, though, since, that, paralleled, until, heroism,
# Nearest to often: sometimes, usually, commonly, generally, also, typically, widely, frequently,
# Nearest to system: systems, hercules, ezln, nominal, echelon, reflectance, tourists, ebu,
# Nearest to many: some, several, these, all, various, those, most, certain,
# Nearest to as: without, oo, donnell, delian, by, nisan, casualties, for,
# Nearest to have: had, has, be, having, were, are, narcotics, hayes,
# Nearest to d: b, l, lebowski, c, okavango, rmi, cloth, mandrake,
# Nearest to two: five, four, three, six, seven, eight, one, nine,
# Nearest to only: dowling, positioned, not, icmp, still, below, wink, clearly,
# Nearest to his: her, their, its, my, the, your, our, retinue,
# Nearest to and: or, but, which, including, throughout, in, who, among,
# Nearest to four: five, six, eight, three, seven, nine, two, one,
# Average loss at step 62000: 3.441569
# Average loss at step 64000: 3.356839
# Average loss at step 66000: 3.339273
# Average loss at step 68000: 3.385238
# Average loss at step 70000: 3.369649
# Nearest to are: were, is, have, telecoms, include, although, be, those,
# Nearest to eight: six, seven, nine, five, four, three, two, zero,
# Nearest to from: through, into, during, sneaking, towards, in, icelanders, after,
# Nearest to the: its, their, his, her, a, this, mendoza, any,
# Nearest to however: but, although, though, that, when, since, founded, until,
# Nearest to often: sometimes, usually, generally, commonly, typically, also, now, widely,
# Nearest to system: systems, ebu, sinless, network, hercules, nominal, echelon, global,
# Nearest to many: some, several, all, these, various, most, certain, such,
# Nearest to as: donnell, oo, cubans, before, authoritative, headland, jalalabad, while,
# Nearest to have: had, has, were, are, be, include, having, choose,
# Nearest to d: b, c, okavango, simulators, lebowski, r, l, lynched,
# Nearest to two: three, four, eight, five, seven, six, one, nine,
# Nearest to only: grimaldi, dowling, positioned, clearly, terrains, planet, rosalyn, until,
# Nearest to his: her, their, my, its, the, your, whose, s,
# Nearest to and: or, but, while, orbs, although, including, autonomously, than,
# Nearest to four: five, six, eight, seven, nine, three, two, zero,
# Average loss at step 72000: 3.402122
# Average loss at step 74000: 3.393969
# Average loss at step 76000: 3.347632
# Average loss at step 78000: 3.233976
# Average loss at step 80000: 3.373457
# Nearest to are: were, have, is, include, while, those, be, although,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to from: through, into, towards, during, sneaking, before, warehouse, since,
# Nearest to the: any, its, this, their, his, a, our, some,
# Nearest to however: but, although, though, when, and, that, thus, paralleled,
# Nearest to often: sometimes, usually, generally, commonly, also, typically, now, still,
# Nearest to system: systems, nominal, reflectance, network, process, echelon, global, morse,
# Nearest to many: several, some, these, various, most, all, numerous, certain,
# Nearest to as: ubuntu, by, tubulin, ayya, when, rumford, frankenchrist, like,
# Nearest to have: had, has, are, were, be, having, contain, include,
# Nearest to d: b, c, l, simulators, diamond, sean, okavango, lynched,
# Nearest to two: three, one, four, six, seven, five, eight, zero,
# Nearest to only: grimaldi, dowling, always, positioned, not, nearly, usually, platter,
# Nearest to his: her, their, my, its, your, the, cyrenaica, our,
# Nearest to and: or, but, while, however, including, ase, of, cleaved,
# Nearest to four: seven, six, five, three, eight, nine, zero, two,
# Average loss at step 82000: 3.293581
# Average loss at step 84000: 3.342463
# Average loss at step 86000: 3.345703
# Average loss at step 88000: 3.323397
# Average loss at step 90000: 3.242213
# Nearest to are: were, is, have, include, was, although, those, grattan,
# Nearest to eight: nine, seven, five, six, four, three, two, zero,
# Nearest to from: through, sneaking, in, during, after, towards, by, fulfilling,
# Nearest to the: a, its, his, this, executor, their, scepticism, crumbs,
# Nearest to however: but, although, though, while, since, that, when, if,
# Nearest to often: usually, sometimes, generally, commonly, typically, still, frequently, now,
# Nearest to system: systems, reflectance, process, parse, ebu, hercules, network, echelon,
# Nearest to many: some, several, various, all, numerous, these, most, certain,
# Nearest to as: ubuntu, for, oo, donnell, before, lengthy, delian, swiss,
# Nearest to have: had, has, be, are, were, having, narcotics, hayes,
# Nearest to d: b, c, lebowski, sean, simulators, okavango, pr, rmi,
# Nearest to two: three, five, four, seven, six, eight, one, zero,
# Nearest to only: until, grimaldi, absolutive, never, but, first, initially, nearly,
# Nearest to his: her, their, its, my, your, cyrenaica, our, maneuvering,
# Nearest to and: or, but, including, american, autonomously, of, b, who,
# Nearest to four: six, seven, three, five, eight, nine, two, zero,
# Average loss at step 92000: 2.740636
# Average loss at step 94000: 3.104030
# Average loss at step 96000: 3.065708
# Average loss at step 98000: 3.217209
# Average loss at step 100000: 3.281638
# Nearest to are: were, include, is, have, those, telecoms, exist, although,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to from: through, sneaking, in, towards, between, hatcher, hentai, after,
# Nearest to the: a, their, any, its, this, his, our, some,
# Nearest to however: but, although, though, while, that, when, if, and,
# Nearest to often: sometimes, usually, generally, commonly, also, typically, frequently, still,
# Nearest to system: systems, reflectance, process, echelon, hercules, network, ebu, parse,
# Nearest to many: several, some, various, these, numerous, all, those, both,
# Nearest to as: oo, donnell, ubuntu, documented, jalalabad, ayya, cgpm, cubans,
# Nearest to have: had, has, having, be, are, were, narcotics, include,
# Nearest to d: b, c, thespis, lebowski, lynched, althea, pr, okavango,
# Nearest to two: three, four, five, six, one, zero, seven, eight,
# Nearest to only: first, absolutive, until, initially, grimaldi, never, always, still,
# Nearest to his: her, their, its, whose, my, s, your, the,
# Nearest to and: but, or, including, however, while, like, which, although,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
data_index = 0
 
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
def generate_batch_CBOW(batch_size,nump_skips,skip_window):
  labels,batch = generate_batch(batch_size,num_skips,skip_window)
  labels.shape = (labels.shape[0],1)
  batch.shape = (batch.shape[0],)
  return batch,labels

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.compat.v1.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.compat.v1.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.compat.v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.compat.v1.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.compat.v1.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.compat.v1.Session(graph=graph) as session:
  tf.compat.v1.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_CBOW(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.356615
# Nearest to as: quake, js, chiao, thoroughbreds, seo, parabola, ruling, react,
# Nearest to s: macrobiotics, frantz, omission, grab, columbian, privatizing, leveled, emory,
# Nearest to state: conform, coup, infirmary, portmanteau, ill, construction, disappear, hess,
# Nearest to over: aldehyde, stated, secluded, larnaca, bowel, dutt, imap, road,
# Nearest to UNK: provincia, flavorings, jordanes, grindcore, decommissioned, gown, clifton, biome,
# Nearest to time: missionary, ordination, courageous, brundtland, boh, newer, memphis, saturnalia,
# Nearest to for: divulge, epimorphism, keyser, liberia, offensively, maternal, urls, cont,
# Nearest to the: voters, conveniently, batavia, rdenas, fractal, louisbourg, balkh, sock,
# Nearest to two: circuitry, servo, erfurt, amalric, orig, barnum, hinders, museums,
# Nearest to more: ca, fort, consultancy, ber, statist, wash, pondering, nelly,
# Nearest to between: rural, ov, malevolent, bodmin, captivity, jansen, contractors, passed,
# Nearest to history: apps, marek, buying, delusion, aires, greed, currently, supplement,
# Nearest to use: port, mayfair, augusto, congressmen, thinly, grill, infra, curonian,
# Nearest to his: elle, assr, mattered, lucas, andean, attributing, tiu, allies,
# Nearest to one: daydream, antichrist, folsom, submit, meals, ici, dynastic, perpetually,
# Nearest to a: predictability, real, antigonus, boise, detract, womanizer, muharram, suleiman,
# Average loss at step 2000: 4.365927
# Average loss at step 4000: 3.863912
# Average loss at step 6000: 3.790500
# Average loss at step 8000: 3.693030
# Average loss at step 10000: 3.613402
# Nearest to as: rations, loses, galindo, polyphonic, ricimer, piped, impair, have,
# Nearest to s: his, emory, and, was, or, cornelis, diamagnets, schooled,
# Nearest to state: examples, conform, duckling, construction, berenson, quota, ill, utc,
# Nearest to over: every, stated, melrose, road, larnaca, secluded, aching, aldehyde,
# Nearest to UNK: jordanes, liberal, manipulations, manned, sibilant, wrought, buckinghamshire, lap,
# Nearest to time: missionary, ewes, gilmour, ordination, mindset, derleth, goblins, hyde,
# Nearest to for: dentistry, epileptic, of, with, in, ignorance, into, urls,
# Nearest to the: a, its, this, his, customizable, an, rump, excommunicate,
# Nearest to two: three, four, five, seven, eight, six, nine, one,
# Nearest to more: nelly, ca, statist, antisymmetric, bosnia, straddle, modem, ber,
# Nearest to between: in, malevolent, rural, barren, with, of, passed, dramatist,
# Nearest to history: apps, buying, motorists, yellow, university, jiang, obelisk, cth,
# Nearest to use: diffuse, adversarial, firefox, farian, mayfair, grill, thinly, excavated,
# Nearest to his: her, their, its, the, s, elle, fenway, caen,
# Nearest to one: two, three, seven, six, four, eight, bassline, cylinder,
# Nearest to a: the, balfour, obadiah, ric, this, une, disagreed, como,
# Average loss at step 12000: 3.609742
# Average loss at step 14000: 3.575133
# Average loss at step 16000: 3.414924
# Average loss at step 18000: 3.455499
# Average loss at step 20000: 3.538237
# Nearest to as: galindo, apoptotic, nc, mercantile, ideation, collectibles, eleventh, in,
# Nearest to s: aquilonia, deadlock, pastiches, and, cornelis, vai, assesses, pai,
# Nearest to state: conform, duckling, construction, quota, spurs, artefact, playboy, examples,
# Nearest to over: road, every, melrose, aching, aldehyde, secluded, stated, midtown,
# Nearest to UNK: net, shipments, bowled, mathematician, rfc, e, diachronic, renunciation,
# Nearest to time: vote, way, gilmour, hyde, ewes, anatomical, missionary, support,
# Nearest to for: in, dentistry, by, with, of, mbox, passenger, vegetation,
# Nearest to the: their, its, any, this, his, an, a, slopes,
# Nearest to two: three, six, four, five, eight, one, seven, zero,
# Nearest to more: less, most, nelly, fairly, larger, statist, greater, antisymmetric,
# Nearest to between: in, malevolent, with, rural, barren, dramatist, sipe, swinburne,
# Nearest to history: apps, university, cth, motorists, book, buying, supports, poised,
# Nearest to use: adversarial, replay, updates, success, most, regrettable, firefox, mayfair,
# Nearest to his: their, her, its, the, rush, sealing, firsts, secluded,
# Nearest to one: two, three, four, six, seven, eight, five, nine,
# Nearest to a: this, the, coinciding, any, no, disagreed, ric, fowl,
# Average loss at step 22000: 3.502453
# Average loss at step 24000: 3.493072
# Average loss at step 26000: 3.479715
# Average loss at step 28000: 3.477583
# Average loss at step 30000: 3.504936
# Nearest to as: under, by, amraam, donor, including, collectibles, overman, galindo,
# Nearest to s: his, rhythmic, xxxviii, mays, ostpolitik, invariant, afloat, ata,
# Nearest to state: conform, cluniac, construction, duckling, spurs, psychoanalytic, hess, playboy,
# Nearest to over: road, melrose, every, midtown, secluded, aching, precision, starfighter,
# Nearest to UNK: gerd, h, pausanias, arsenate, anywhere, assumptions, hussain, wahhabism,
# Nearest to time: vote, heron, way, year, gilmour, anatomical, attesting, interstitial,
# Nearest to for: of, signature, when, dentistry, to, newsted, with, kjv,
# Nearest to the: their, its, his, budge, a, acrobatic, uncompetitive, reckoning,
# Nearest to two: four, three, five, one, seven, eight, six, zero,
# Nearest to more: less, most, larger, fairly, greater, very, nelly, gi,
# Nearest to between: with, in, malevolent, dramatist, from, barren, outside, rural,
# Nearest to history: apps, university, book, fang, motorists, motion, cth, supports,
# Nearest to use: plh, woolly, adversarial, subversion, most, ingrained, anchovies, context,
# Nearest to his: their, her, its, the, s, gastric, sealing, rush,
# Nearest to one: two, seven, four, five, six, eight, three, nine,
# Nearest to a: no, any, the, ike, another, pains, gtpases, fours,
# Average loss at step 32000: 3.500689
# Average loss at step 34000: 3.492459
# Average loss at step 36000: 3.458796
# Average loss at step 38000: 3.299954
# Average loss at step 40000: 3.430669
# Nearest to as: tupelo, nc, gluon, galindo, impair, forging, by, collectibles,
# Nearest to s: his, salient, annotations, pita, pickled, creditor, gutierrez, alchemical,
# Nearest to state: construction, hess, psychoanalytic, duckling, conform, cluniac, spurs, quota,
# Nearest to over: melrose, every, wilton, road, aching, throughout, depress, within,
# Nearest to UNK: blackmailed, heterozygote, le, d, manipulations, albert, testable, satem,
# Nearest to time: vote, way, year, heron, footnotes, crispy, sprache, generalizing,
# Nearest to for: by, when, to, if, in, epimorphism, of, signature,
# Nearest to the: its, his, their, each, any, this, a, involuntary,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to more: less, most, greater, very, nelly, fairly, larger, rather,
# Nearest to between: with, from, malevolent, outside, zooming, dramatist, punishing, lordship,
# Nearest to history: apps, antisymmetric, fang, philosophy, list, book, marek, supports,
# Nearest to use: sense, plh, form, policymakers, woolly, ibizan, dwell, subversion,
# Nearest to his: her, their, its, the, s, tico, my, caen,
# Nearest to one: seven, four, two, six, five, eight, three, nine,
# Nearest to a: coinciding, the, any, another, predictability, gtpases, or, heterozygote,
# Average loss at step 42000: 3.435688
# Average loss at step 44000: 3.459203
# Average loss at step 46000: 3.452946
# Average loss at step 48000: 3.351095
# Average loss at step 50000: 3.384298
# Nearest to as: tupelo, donor, gematria, euphrates, became, loses, pangloss, commissioning,
# Nearest to s: and, ostpolitik, whose, his, sexton, cornelis, twins, tollens,
# Nearest to state: psychoanalytic, duckling, hess, construction, cluniac, acceleration, repetition, officials,
# Nearest to over: on, melrose, neburg, off, midtown, cycle, throughout, aching,
# Nearest to UNK: blackmailed, embryo, de, shipments, paleontology, duc, newsreel, commissioning,
# Nearest to time: way, year, period, vote, generalizing, progressing, syllable, day,
# Nearest to for: while, before, if, after, and, during, from, of,
# Nearest to the: its, their, this, his, a, hexagonal, some, petitioning,
# Nearest to two: six, one, three, four, eight, seven, five, nine,
# Nearest to more: less, most, greater, larger, fairly, very, nelly, highly,
# Nearest to between: with, in, from, dramatist, yucatan, methionine, malevolent, lordship,
# Nearest to history: apps, philosophy, list, book, antisymmetric, post, etymology, asparagales,
# Nearest to use: sense, most, form, policymakers, teach, context, mohair, dwell,
# Nearest to his: their, her, its, my, the, your, s, him,
# Nearest to one: two, six, eight, seven, four, five, nine, three,
# Nearest to a: coinciding, the, any, patchy, another, detract, anion, no,
# Average loss at step 52000: 3.438149
# Average loss at step 54000: 3.428547
# Average loss at step 56000: 3.436576
# Average loss at step 58000: 3.395239
# Average loss at step 60000: 3.391208
# Nearest to as: altercation, loses, became, bain, collectibles, tupelo, humanistic, without,
# Nearest to s: ostpolitik, gutierrez, clique, salient, whose, sprinter, although, mulroney,
# Nearest to state: hess, duckling, construction, cluniac, psychoanalytic, loss, conform, acceleration,
# Nearest to over: melrose, about, throughout, into, midtown, within, on, wilton,
# Nearest to UNK: seams, jewellery, ism, dlr, troupe, thierry, capri, arsenate,
# Nearest to time: way, period, year, vote, quarter, problem, syllable, generalizing,
# Nearest to for: when, if, of, meantime, battista, manometer, signature, in,
# Nearest to the: its, their, a, this, some, any, each, informing,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to more: less, greater, larger, fairly, most, very, rather, other,
# Nearest to between: with, among, yucatan, thailand, in, malevolent, swinburne, from,
# Nearest to history: list, apps, philosophy, cena, jiang, post, origins, demographics,
# Nearest to use: sense, most, dwell, allow, adversity, extend, means, fade,
# Nearest to his: her, their, its, my, your, nessus, the, advancing,
# Nearest to one: six, two, four, seven, eight, five, nine, three,
# Nearest to a: the, another, any, every, presse, coinciding, recharge, ola,
# Average loss at step 62000: 3.241929
# Average loss at step 64000: 3.256955
# Average loss at step 66000: 3.403924
# Average loss at step 68000: 3.392924
# Average loss at step 70000: 3.363227
# Nearest to as: calhoun, loses, before, departmental, apoptotic, because, bront, entendre,
# Nearest to s: salient, the, sexton, symmetry, isbn, gutierrez, whose, currying,
# Nearest to state: states, officials, hess, spurs, psychoanalytic, license, ridinghood, repetition,
# Nearest to over: about, flipped, midtown, wilton, melrose, throughout, crispin, within,
# Nearest to UNK: blade, overpowered, projects, rescuers, aldo, bi, acuff, pen,
# Nearest to time: way, quarter, problem, period, generalizing, distance, gemma, heron,
# Nearest to for: in, of, if, including, at, while, to, after,
# Nearest to the: their, its, any, a, each, this, another, some,
# Nearest to two: three, four, six, five, seven, zero, one, eight,
# Nearest to more: less, most, very, fairly, larger, greater, rather, grouped,
# Nearest to between: with, among, around, within, in, malevolent, yucatan, swinburne,
# Nearest to history: list, period, apps, cena, philosophy, capitalism, post, origins,
# Nearest to use: most, allow, sense, form, tolvaj, extend, using, sahrawi,
# Nearest to his: her, their, its, my, your, the, our, him,
# Nearest to one: seven, two, eight, six, four, five, nine, three,
# Nearest to a: the, another, coinciding, gtpases, any, unpopular, reenactment, jewels,
# Average loss at step 72000: 3.373946
# Average loss at step 74000: 3.346749
# Average loss at step 76000: 3.314694
# Average loss at step 78000: 3.353347
# Average loss at step 80000: 3.376863
# Nearest to as: impair, entendre, calhoun, nc, gematria, departmental, after, burnt,
# Nearest to s: sexton, lamarr, rocking, hypnosis, pita, gutierrez, shapur, gujarati,
# Nearest to state: hess, county, city, psychoanalytic, states, spurs, repetition, artefact,
# Nearest to over: about, off, flipped, melrose, around, between, within, wilton,
# Nearest to UNK: kirchhoff, packard, uppercase, o, johnson, heathrow, ul, brown,
# Nearest to time: year, way, heron, generalizing, problem, quarter, fanbase, distance,
# Nearest to for: including, while, amerindian, through, against, when, taxicab, with,
# Nearest to the: its, this, their, a, each, involuntary, another, his,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to more: less, very, most, greater, fairly, larger, rather, grouped,
# Nearest to between: among, around, within, yucatan, over, with, in, from,
# Nearest to history: list, period, apps, etymology, beauty, origins, stooges, capitalism,
# Nearest to use: sense, allow, most, extend, bring, sahrawi, accept, form,
# Nearest to his: her, their, my, its, your, our, the, personal,
# Nearest to one: six, seven, two, three, eight, four, five, nine,
# Nearest to a: the, another, coinciding, barbosa, every, gtpases, anion, quite,
# Average loss at step 82000: 3.406278
# Average loss at step 84000: 3.406978
# Average loss at step 86000: 3.385550
# Average loss at step 88000: 3.355905
# Average loss at step 90000: 3.364943
# Nearest to as: tupelo, loses, gematria, searchable, bront, departmental, besht, winger,
# Nearest to s: gutierrez, whose, promiscuous, servicemen, tollens, mays, xxxviii, cretian,
# Nearest to state: hess, spurs, city, county, beau, construction, aten, skates,
# Nearest to over: off, about, around, through, flipped, scoop, within, melrose,
# Nearest to UNK: uninhabited, ridings, wesley, gwh, amtrak, kenneth, cheetah, aphorisms,
# Nearest to time: year, period, distance, vote, generalizing, attesting, heron, syllable,
# Nearest to for: of, including, after, while, when, without, rebounds, manometer,
# Nearest to the: its, this, another, each, a, their, acrobatic, his,
# Nearest to two: three, five, four, six, eight, seven, zero, one,
# Nearest to more: less, most, very, greater, fairly, quite, rather, larger,
# Nearest to between: among, with, around, within, yucatan, in, barren, over,
# Nearest to history: list, period, book, apps, origins, beauty, asparagales, etymology,
# Nearest to use: most, sense, support, extend, dwell, allow, syntax, because,
# Nearest to his: her, their, its, my, your, our, the, dashiell,
# Nearest to one: seven, four, eight, six, two, three, five, nine,
# Nearest to a: coinciding, another, every, the, gtpases, opacity, any, patchy,
# Average loss at step 92000: 3.402486
# Average loss at step 94000: 3.247413
# Average loss at step 96000: 3.364502
# Average loss at step 98000: 3.244676
# Average loss at step 100000: 3.361850
# Nearest to as: pangloss, burnt, by, voip, tupelo, besht, loses, replicants,
# Nearest to s: whose, ostpolitik, kirby, salient, his, gutierrez, alchemical, sexton,
# Nearest to state: spurs, hess, county, states, repetition, beau, officials, city,
# Nearest to over: off, about, melrose, through, around, between, scoop, precedes,
# Nearest to UNK: arsenate, hagia, unencumbered, hatches, blackmailed, birkenau, contradicted, businessman,
# Nearest to time: year, way, generalizing, vote, survival, syllable, gemma, jesu,
# Nearest to for: without, including, when, against, after, while, before, urbanisation,
# Nearest to the: its, their, your, his, a, this, some, misplaced,
# Nearest to two: four, three, five, six, one, eight, seven, zero,
# Nearest to more: less, most, very, fairly, greater, larger, quite, propagandist,
# Nearest to between: with, among, around, within, malevolent, over, yucatan, gnome,
# Nearest to history: list, atmospheres, beauty, book, apps, capitalism, lists, demographics,
# Nearest to use: sense, syntax, support, most, extend, muay, bread, grenades,
# Nearest to his: her, their, my, your, its, our, the, s,
# Nearest to one: two, four, seven, eight, five, six, nine, three,
# Nearest to a: coinciding, another, the, any, gtpases, presse, detract, chapman,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
