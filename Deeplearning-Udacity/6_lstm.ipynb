# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.compat.v1.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.compat.v1.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.compat.v1.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.compat.v1.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.compat.v1.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.compat.v1.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.compat.v1.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.compat.v1.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.compat.v1.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.compat.v1.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.compat.v1.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.compat.v1.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.compat.v1.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.compat.v1.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.compat.v1.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.compat.v1.Session(graph=graph) as session:
  tf.compat.v1.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.298632 learning rate: 10.000000
# Minibatch perplexity: 27.08
# ================================================================================
# vnjsyzsci  dbuxhqfcolfsjizlt lefssieqyrosonnnuatesdutmba lthtxainc ue s ynseijvy
# wocehqlvot tpujf dqi ajka tlz gtxndncabrpzx mn  dozjfvvsmhscthhvxvmni hnwyrtxglp
# w goe nwg jvurd axxtstcaseyztshrjemj alchtfvd etavbsapnoiv iaairzdm igqrqvl w si
# yisbuiei peuuhw egttd qreryloouwig zcokyglrgh rgolqetggtiooplmeomey wecp   anatn
# qa euydospxf pj bxnaoiis tl r  nchovr aij crpbujrew ucd tgksjkygfhkiesaaakdypxdh
# ================================================================================
# Validation set perplexity: 20.26
# Average loss at step 100: 2.592752 learning rate: 10.000000
# Minibatch perplexity: 11.21
# Validation set perplexity: 10.39
# Average loss at step 200: 2.251766 learning rate: 10.000000
# Minibatch perplexity: 8.78
# Validation set perplexity: 8.72
# Average loss at step 300: 2.101399 learning rate: 10.000000
# Minibatch perplexity: 7.43
# Validation set perplexity: 8.14
# Average loss at step 400: 1.995679 learning rate: 10.000000
# Minibatch perplexity: 7.58
# Validation set perplexity: 7.52
# Average loss at step 500: 1.924856 learning rate: 10.000000
# Minibatch perplexity: 6.35
# Validation set perplexity: 6.82
# Average loss at step 600: 1.894360 learning rate: 10.000000
# Minibatch perplexity: 6.36
# Validation set perplexity: 6.67
# Average loss at step 700: 1.845400 learning rate: 10.000000
# Minibatch perplexity: 6.42
# Validation set perplexity: 6.31
# Average loss at step 800: 1.798725 learning rate: 10.000000
# Minibatch perplexity: 5.89
# Validation set perplexity: 6.27
# Average loss at step 900: 1.808105 learning rate: 10.000000
# Minibatch perplexity: 6.67
# Validation set perplexity: 6.06
# Average loss at step 1000: 1.803146 learning rate: 10.000000
# Minibatch perplexity: 5.62
# ================================================================================
# ally des the elet ophather hewre one eight spor encoring vainf wecturally relopi
# jake and an in sever perter the comprent in muerce edionile no de he whele wrost
# ben in the eack for hy agon guster dearo sirges the sute in wele vingal dearme h
# ed vering preice in yinibe in niz ha lan offes this fecely with it hissimii b lo
# ge pidicter from ribarian woud termenty the one one nine seven two gatuer s it i
# ================================================================================
# Validation set perplexity: 5.92
# Average loss at step 1100: 1.752224 learning rate: 10.000000
# Minibatch perplexity: 5.50
# Validation set perplexity: 5.69
# Average loss at step 1200: 1.731229 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 5.41
# Average loss at step 1300: 1.715180 learning rate: 10.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 5.38
# Average loss at step 1400: 1.726907 learning rate: 10.000000
# Minibatch perplexity: 5.83
# Validation set perplexity: 5.28
# Average loss at step 1500: 1.717665 learning rate: 10.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 5.17
# Average loss at step 1600: 1.730371 learning rate: 10.000000
# Minibatch perplexity: 5.41
# Validation set perplexity: 5.18
# Average loss at step 1700: 1.694579 learning rate: 10.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 5.13
# Average loss at step 1800: 1.658720 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 4.99
# Average loss at step 1900: 1.630942 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.82
# Average loss at step 2000: 1.673496 learning rate: 10.000000
# Minibatch perplexity: 5.58
# ================================================================================
# gning the cashoctualies have persisms hiscn and the pectaing not abnobeled best
# quagies and siffinition normeniak wratts of a sligning to sounced all to bumains
# fray sponsive at s exprodatrarded often in a hunl the mast unital largeary const
# m constinntainex of the fill natern one nida it aldosias wated the numbers her h
# uding jonds and jusside makers and mission masion than govisings ad knanghounk o
# ================================================================================
# Validation set perplexity: 4.98
# Average loss at step 2100: 1.663202 learning rate: 10.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.71
# Average loss at step 2200: 1.658062 learning rate: 10.000000
# Minibatch perplexity: 6.38
# Validation set perplexity: 4.71
# Average loss at step 2300: 1.622627 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.64
# Average loss at step 2400: 1.643245 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 4.57
# Average loss at step 2500: 1.657445 learning rate: 10.000000
# Minibatch perplexity: 5.22
# Validation set perplexity: 4.55
# Average loss at step 2600: 1.631031 learning rate: 10.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 4.50
# Average loss at step 2700: 1.638121 learning rate: 10.000000
# Minibatch perplexity: 4.53
# Validation set perplexity: 4.56
# Average loss at step 2800: 1.631195 learning rate: 10.000000
# Minibatch perplexity: 5.41
# Validation set perplexity: 4.42
# Average loss at step 2900: 1.630431 learning rate: 10.000000
# Minibatch perplexity: 5.61
# Validation set perplexity: 4.53
# Average loss at step 3000: 1.633432 learning rate: 10.000000
# Minibatch perplexity: 4.94
# ================================================================================
# dsy oday afterred his ararata may stypt ane is duck one of blature become in bas
# net rise introducers oas  spebic and f which andy jak all awagelatsal offic and
# low theore as in as for to his tage patifive daqine estoolled mannillatold in re
# ests roiting he parto the after jan to with night na of becames the wolly complo
# ver haynologis eupower and this supformation chlodopragrain pass fultionity of a
# ================================================================================
# Validation set perplexity: 4.52
# Average loss at step 3100: 1.612898 learning rate: 10.000000
# Minibatch perplexity: 5.72
# Validation set perplexity: 4.51
# Average loss at step 3200: 1.628033 learning rate: 10.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 4.42
# Average loss at step 3300: 1.623894 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 4.26
# Average loss at step 3400: 1.649121 learning rate: 10.000000
# Minibatch perplexity: 5.46
# Validation set perplexity: 4.43
# Average loss at step 3500: 1.642428 learning rate: 10.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 4.43
# Average loss at step 3600: 1.651711 learning rate: 10.000000
# Minibatch perplexity: 4.35
# Validation set perplexity: 4.35
# Average loss at step 3700: 1.628987 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.35
# Average loss at step 3800: 1.629499 learning rate: 10.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 4.47
# Average loss at step 3900: 1.619674 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 4.43
# Average loss at step 4000: 1.637185 learning rate: 10.000000
# Minibatch perplexity: 4.70
# ================================================================================
# s dend his old consect of the polas inolly the freedom his la state most fictay
# chersonia slanse for film with aptost americe is life greenta fold ho sphe cod s
# jonusic citee the many there zero two nine six eight zero eact preferse more lif
# el intulthsnotus the ungentance eviling todomu were carpent wour vapaen directio
# bown epon two nine one yeitry adbackann over is seven of this resairs shodoods o
# ================================================================================
# Validation set perplexity: 4.50
# Average loss at step 4100: 1.614038 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.46
# Average loss at step 4200: 1.617093 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.26
# Average loss at step 4300: 1.598585 learning rate: 10.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.26
# Average loss at step 4400: 1.591039 learning rate: 10.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 4.26
# Average loss at step 4500: 1.596763 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 4.52
# Average loss at step 4600: 1.598047 learning rate: 10.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.47
# Average loss at step 4700: 1.609580 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.33
# Average loss at step 4800: 1.616542 learning rate: 10.000000
# Minibatch perplexity: 4.35
# Validation set perplexity: 4.29
# Average loss at step 4900: 1.614769 learning rate: 10.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.44
# Average loss at step 5000: 1.593126 learning rate: 1.000000
# Minibatch perplexity: 4.41
# ================================================================================
# cherial two zero two zero zero and to any storating ed po by is parl or thes pen
# missy zero zero zero five two appolitive one early thoughound natt of goanoquers
# wy at the consest it oded that thus field  legwere broughtated twammongh conces
# came of mages discale elemies productan in the subc estcal to so word itselfty w
# d more on kallfa two zero zern freect graute one nine one one seven zero s risex
# ================================================================================
# Validation set perplexity: 4.50
# Average loss at step 5100: 1.589335 learning rate: 1.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.30
# Average loss at step 5200: 1.575531 learning rate: 1.000000
# Minibatch perplexity: 4.57
# Validation set perplexity: 4.24
# Average loss at step 5300: 1.562271 learning rate: 1.000000
# Minibatch perplexity: 4.60
# Validation set perplexity: 4.24
# Average loss at step 5400: 1.561061 learning rate: 1.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 4.24
# Average loss at step 5500: 1.546556 learning rate: 1.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 4.20
# Average loss at step 5600: 1.564235 learning rate: 1.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.18
# Average loss at step 5700: 1.552709 learning rate: 1.000000
# Minibatch perplexity: 4.56
# Validation set perplexity: 4.18
# Average loss at step 5800: 1.566506 learning rate: 1.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.19
# Average loss at step 5900: 1.556562 learning rate: 1.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.20
# Average loss at step 6000: 1.526382 learning rate: 1.000000
# Minibatch perplexity: 4.80
# ================================================================================
# cheuganguates president was s nent in lifuts frot basson in abor one eight six o
# f chthylicals respects publytank a version of may mibline known spem tost donst
#  which in that is and the unomic which descrobjecture orgations jany popular the
# jeatiter revolugies infinary the kajons also the auriland is representic large i
#  hade case most combounctian precester arlusize in the formulage ainion singe be
# ================================================================================
# Validation set perplexity: 4.19
# Average loss at step 6100: 1.547293 learning rate: 1.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.16
# Average loss at step 6200: 1.521929 learning rate: 1.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.16
# Average loss at step 6300: 1.526897 learning rate: 1.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.17
# Average loss at step 6400: 1.519953 learning rate: 1.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 4.15
# Average loss at step 6500: 1.536546 learning rate: 1.000000
# Minibatch perplexity: 4.49
# Validation set perplexity: 4.14
# Average loss at step 6600: 1.576475 learning rate: 1.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 4.15
# Average loss at step 6700: 1.559600 learning rate: 1.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 4.17
# Average loss at step 6800: 1.582331 learning rate: 1.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 4.15
# Average loss at step 6900: 1.567277 learning rate: 1.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 4.17
# Average loss at step 7000: 1.558475 learning rate: 1.000000
# Minibatch perplexity: 5.04
# ================================================================================
# t rud vited to two three the ransttern and conducs shon art gows of vortharitien
# ller communies with rul nationary may de player a refreed elytwone the people of
# quess unergan dilly to ebrengly pice to from the general and than and a nesef mo
# ing with as be afarial been stited hiesh recolor excuried becuused as award and
# dociab what articleclude after and as compection de prossecmental of commuin a l
# ================================================================================
# Validation set perplexity: 4.15

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# set utf8

url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)

def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))

valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])

char_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
vocabulary_size = char_size**2 #bigram
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

def bigram2id(char):
  return char2id(char[0])*char_size+char2id(char[1])
  
def id2bigram(dictid):
  return id2char(dictid//char_size)+id2char(dictid%char_size)

print(bigram2id('ab'), bigram2id('yz'), bigram2id('  '), bigram2id('ïï'))
print(id2bigram(1), id2bigram(265), id2bigram(0))

batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // (batch_size*2)
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, bigram2id(self._text[self._cursor[b]]+self._text[self._cursor[b]+1])] = 1.0
      self._cursor[b] = (self._cursor[b] + 2) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2bigram(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))

def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

num_nodes = 64
embedding_dimension = 100

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  embedding = tf.Variable(tf.compat.v1.random_uniform([vocabulary_size,embedding_dimension],minval=-1.0,maxval=1.0))

  #ifco
  gate_count=4
  lstmw = tf.Variable(tf.compat.v1.truncated_normal([embedding_dimension+num_nodes, num_nodes*gate_count], -0.1, 0.1))
  lstmb = tf.Variable(tf.zeros([1, num_nodes*gate_count]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.compat.v1.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state,train=False):
    if train:
      io=tf.concat(1,[tf.nn.dropout(i,0.5),o])
    else:
      io=tf.concat(1,[i,o])
    values = tf.split(1,gate_count,tf.matmul(io,lstmw)+lstmb)
    input_gate = tf.sigmoid(values[0])
    forget_gate = tf.sigmoid(values[1])
    update = values[2]
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(values[3])
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.compat.v1.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    #embedi = tf.nn.embedding_lookup(embedding,i)
    embedi = tf.matmul(i,embedding)
    output, state = lstm_cell(embedi, output, state,train=True)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0,outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(0,train_labels), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.compat.v1.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.compat.v1.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  #sample_embed = tf.nn.embedding_lookup(embedding,sample_input)
  sample_embed = tf.matmul(sample_input,embedding)
  sample_output, sample_state = lstm_cell(
    sample_embed, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

num_steps = 7001
summary_frequency = 100

with tf.compat.v1.Session(graph=graph) as session:
  tf.compat.v1.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Found and verified text8.zip
# Data size 100000000
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl
# Unexpected character: ï
# Unexpected character: ï
# 29 701 0 0
#  a iv
# ['ons anarchists advocat', 'nomination gore s endo', 'when military governme', ' three nine one six ze', 'lleria arches national', 'reviated as dr mr and ', ' abbeys and monasterie', 'shing the right of app', 'married urraca princes', 'sity upset the devils ', 'hel and richard baer h', 'ased in the st family ', 'y and liturgical langu', ' disgust because of th', 'ay opened for passenge', 'society and that this ', 'tion from the national', 'ago based chess record', 'migration took place d', ' zero zero five yaniv ', 'new york other well kn', 'short subject college ', 'he boeing seven six se', 'sgow two young white m', 'e listed with a gloss ', 'lt during this period ', 'eber has probably been', ' not dead naturally an', 'o be made to recognize', 'll s enthusiastic back', 'yer who received the f', 'operates three submari', 'ore significant than i', 'rmines security of the', 'a fierce critic of the', ' fuel extracted from t', ' two six eight in sign', 'ature that was attacki', 'aristotle s uncaused c', 'e dragas constantine i', 'ity can be lost as in ', 'ecombinant region and ', ' and intracellular ice', 'tensive manufacturing ', 'tion of the size of th', 'he attack from hyrsyl ', 'dy to pass him a stick', 'ed to bring good fortu', 'f certain drugs confus', 'french jansenist theol', 'at it will take to com', 'tion from euclidean ge', 'e convince the priest ', 'ither spontaneously or', 'ent told him to name i', 'argest partner of the ', 'ampaign and barred att', 'ce in a special cell n', 'rver side standard for', 'gain the amplified sig', 'ious texts such as eso', ' assignment of numbers', 'o capitalize on the gr', 'rettas francis poulenc']
# ['ate social relations b', 'dorsement of dean was ', 'ments failed to revive', 'zero two zero zero one', 'al park photographic v', 'd mrs respectively the', 'ies index sacred desti', 'ppeal to the judicial ', 'ess of castile daughte', 's which cost the schoo', ' h provided a detailed', 'y here they are in rou', 'guage among jews manda', 'the relationship betwe', 'gers in december one n', 's neglect is the true ', 'al media and from pres', 'rds label the influenc', ' during the one nine e', 'v shaked and avishai w', 'known manufacturers of', 'e humor one nine three', 'seven a widebody jet w', ' men whose murderers w', 's covering some of the', 'd however the iran ira', 'en one of the most inf', 'and hangs herself upon', 'ze single acts of meri', 'cking darwin read his ', ' first card from the d', 'rines based in talcahu', ' in jersey and guernse', 'he system provided tha', 'he poverty and social ', ' the ground by undergr', 'gns of humanity vol th', 'king his livestock it ', ' cause so aquinas come', ' i of imereti constant', 'n denaturalization and', 'd the diode becomes co', 'ce formation solution ', 'g sectors the question', 'the input usually meas', 'l northwards and reach', 'ck to pull him out but', 'tune to those who carr', 'usion inability to ori', 'ologian b one six thre', 'omplete an operation c', 'geometry and analysis ', 't of the mistakes of a', 'or have employed in th', ' it fort des moines th', 'e uk has also made it ', 'ttempts by his opponen', ' named down s cell the', 'ormats for mailboxes i', 'ignal from q one is di', 'soteric christianity a', 'rs to positions a play', 'growing popularity of ', 'nc jean philippe ramea']
# [' ana']
# ['narc']
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1818   try:
# -> 1819     c_op = c_api.TF_FinishOperation(op_desc)
#    1820   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Dimension 1 in both shapes must be equal, but are 100 and 64. Shapes are [64,100] and [64,64].
# 	From merging shape 0 with other shapes. for 'concat/concat_dim' (op: 'Pack') with input shapes: [64,100], [64,64].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-8b05f6fada70> in <module>
#     203     #embedi = tf.nn.embedding_lookup(embedding,i)
#     204     embedi = tf.matmul(i,embedding)
# --> 205     output, state = lstm_cell(embedi, output, state,train=True)
#     206     outputs.append(output)
#     207
#
# <ipython-input-20-8b05f6fada70> in lstm_cell(i, o, state, train)
#     177   def lstm_cell(i, o, state,train=False):
#     178     if train:
# --> 179       io=tf.concat(1,[tf.nn.dropout(i,0.5),o])
#     180     else:
#     181       io=tf.concat(1,[i,o])
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\ops\array_ops.py in concat(values, axis, name)
#    1266       ops.convert_to_tensor(
#    1267           axis, name="concat_dim",
# -> 1268           dtype=dtypes.int32).get_shape().assert_is_compatible_with(
#    1269               tensor_shape.scalar())
#    1270       return identity(values[0], name=scope)
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, preferred_dtype, dtype_hint)
#    1048   preferred_dtype = deprecation.deprecated_argument_lookup(
#    1049       "dtype_hint", dtype_hint, "preferred_dtype", preferred_dtype)
# -> 1050   return convert_to_tensor_v2(value, dtype, preferred_dtype, name)
#    1051
#    1052
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1106       name=name,
#    1107       preferred_dtype=dtype_hint,
# -> 1108       as_ref=False)
#    1109
#    1110
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx, accept_symbolic_tensors)
#    1184
#    1185     if ret is None:
# -> 1186       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1187
#    1188     if ret is NotImplemented:
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\ops\array_ops.py in _autopacking_conversion_function(v, dtype, name, as_ref)
#    1115   elif dtype != inferred_dtype:
#    1116     v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
# -> 1117   return _autopacking_helper(v, dtype, name or "packed")
#    1118
#    1119
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\ops\array_ops.py in _autopacking_helper(list_or_tuple, dtype, name)
#    1067           elems_as_tensors.append(
#    1068               constant_op.constant(elem, dtype=dtype, name=str(i)))
# -> 1069       return gen_array_ops.pack(elems_as_tensors, name=scope)
#    1070     else:
#    1071       return converted_elems
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in pack(values, axis, name)
#    6716   axis = _execute.make_int(axis, "axis")
#    6717   _, _, _op = _op_def_lib._apply_op_helper(
# -> 6718         "Pack", values=values, axis=axis, name=name)
#    6719   _result = _op.outputs[:]
#    6720   _inputs_flat = _op.inputs
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     798         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     799                          input_types=input_types, attrs=attr_protos,
# --> 800                          op_def=op_def)
#     801       return output_structure, op_def.is_stateful, op
#     802
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py in create_op(***failed resolving arguments***)
#    3477           input_types=input_types,
#    3478           original_op=self._default_original_op,
# -> 3479           op_def=op_def)
#    3480       self._create_op_helper(ret, compute_device=compute_device)
#    3481     return ret
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1981           op_def, inputs, node_def.attr)
#    1982       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1983                                 control_input_ops)
#    1984
#    1985     # Initialize self._outputs.
#
# D:\Coding\IDE\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1820   except errors.InvalidArgumentError as e:
#    1821     # Convert to ValueError for backwards compatibility.
# -> 1822     raise ValueError(str(e))
#    1823
#    1824   return c_op
#
# ValueError: Dimension 1 in both shapes must be equal, but are 100 and 64. Shapes are [64,100] and [64,64].
# 	From merging shape 0 with other shapes. for 'concat/concat_dim' (op: 'Pack') with input shapes: [64,100], [64,64].
